# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os

# %%
company = pd.read_csv("/home/mustafa/Learning/Projects/Electoral Bond Data Analysis/Dataset/PurchaseData.csv")
party = pd.read_csv("/home/mustafa/Learning/Projects/Electoral Bond Data Analysis/Dataset/EncashmentData.csv")

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19207 entries, 0 to 19206
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date of Purchase  18871 non-null  object
#  1   Purchaser Name    18871 non-null  object
#  2   Denomination      18871 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 450.3+ KB

# %%
party.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20846 entries, 0 to 20845
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date of
# Encashment           20421 non-null  object
#  1   Name of the Political Party  20421 non-null  object
#  2   Denomination                 20421 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 488.7+ KB

# %%
company['Purchaser Name'].nunique()
# Out:
# 1316

# %%
total_amount_given = company.groupby('Purchaser Name')['Denomination'].sum().reset_index()

total_amount_given = total_amount_given.sort_values(by='Denomination',ascending=False)
print(total_amount_given)
# Out:
#                                       Purchaser Name  Denomination
# 354              FUTURE GAMING AND HOTEL SERVICES PR  1.208000e+10
# 652   MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED  8.210000e+09
# 866                    QWIKSUPPLYCHAINPRIVATELIMITED  4.100000e+09
# 417                            HALDIA ENERGY LIMITED  3.770000e+09
# 1248                                 VEDANTA LIMITED  3.756500e+09
# ...                                              ...           ...
# 579                                      KUNAL GUPTA  1.000000e+03
# 718                                    N RAMAMOORTHY  1.000000e+03
# 88                                         ARAVIND S  1.000000e+03
# 814                                   POONAM AGARWAL  1.000000e+03
# 73                     ANKUR SINGHAL S O SH ANIL SIN  1.000000e+03
#
# [1316 rows x 2 columns]

# %%
total_amount_given['Denomination'] = total_amount_given['Denomination']/10000000
print(total_amount_given)
# Out:
#                                       Purchaser Name  Denomination
# 354              FUTURE GAMING AND HOTEL SERVICES PR     1208.0000
# 652   MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED      821.0000
# 866                    QWIKSUPPLYCHAINPRIVATELIMITED      410.0000
# 417                            HALDIA ENERGY LIMITED      377.0000
# 1248                                 VEDANTA LIMITED      375.6500
# ...                                              ...           ...
# 579                                      KUNAL GUPTA        0.0001
# 718                                    N RAMAMOORTHY        0.0001
# 88                                         ARAVIND S        0.0001
# 814                                   POONAM AGARWAL        0.0001
# 73                     ANKUR SINGHAL S O SH ANIL SIN        0.0001
#
# [1316 rows x 2 columns]

# %%
total_amount_received = party.groupby('Name of the Political Party')['Denomination'].sum().reset_index()

total_amount_received = total_amount_received.sort_values(by='Denomination', ascending=False)
print(total_amount_received)
# Out:
#                        Name of the Political Party  Denomination
# 5                             BHARTIYA JANTA PARTY  6.060511e+10
# 3                     ALL INDIA TRINAMOOL CONGRESS  1.609531e+10
# 17         PRESIDENT, ALL INDIA CONGRESS COMMITTEE  1.421866e+10
# 4                           BHARAT RASHTRA SAMITHI  1.214710e+10
# 7                                  BIJU JANATA DAL  7.755000e+09
# 8                          DMK PARTY IN PARLIAMENT  6.390000e+09
# 26          YSR CONGRESS PARTY (YUVAJANA SRAMIKA R  3.370000e+09
# 25                              TELUGU DESAM PARTY  2.188800e+09
# 22                      SHIVSENA (POLITICAL PARTY)  1.583814e+09
# 19                              RASTRIYA JANTA DAL  7.250000e+08
# 0                                  AAM AADMI PARTY  6.545000e+08
# 12                          JANATA DAL ( SECULAR )  4.350000e+08
# 24                        SIKKIM KRANTIKARI MORCHA  3.650000e+08
# ...

# %%
total_amount_received['Denomination'] = total_amount_received['Denomination']/10000000
print(total_amount_received)
# Out:
#                        Name of the Political Party  Denomination
# 5                             BHARTIYA JANTA PARTY     6060.5111
# 3                     ALL INDIA TRINAMOOL CONGRESS     1609.5314
# 17         PRESIDENT, ALL INDIA CONGRESS COMMITTEE     1421.8655
# 4                           BHARAT RASHTRA SAMITHI     1214.7099
# 7                                  BIJU JANATA DAL      775.5000
# 8                          DMK PARTY IN PARLIAMENT      639.0000
# 26          YSR CONGRESS PARTY (YUVAJANA SRAMIKA R      337.0000
# 25                              TELUGU DESAM PARTY      218.8800
# 22                      SHIVSENA (POLITICAL PARTY)      158.3814
# 19                              RASTRIYA JANTA DAL       72.5000
# 0                                  AAM AADMI PARTY       65.4500
# 12                          JANATA DAL ( SECULAR )       43.5000
# 24                        SIKKIM KRANTIKARI MORCHA       36.5000
# ...

# %%
plt.figure(figsize=(8, 8))
plt.pie(total_amount_received['Denomination'], labels=total_amount_received['Name of the Political Party'], autopct='%1.1f%%')
plt.title('Percentage of Total Amount Received by each party')
plt.axis('equal')  
plt.show()

# %%
top_10_parties = total_amount_received.head(10)

plt.figure(figsize=(8, 8))
plt.pie(top_20_parties['Denomination'], labels=top_20_parties['Name of the Political Party'], autopct='%1.1f%%')
plt.title('Percentage of Total Amount Received by Top 10 Parties')
plt.axis('equal')  
plt.show()

# %%
import plotly.graph_objects as go

top_10_parties = total_amount_received.head(10)

fig = go.Figure(data=[go.Pie(labels=top_10_parties['Name of the Political Party'], 
                             values=top_10_parties['Denomination'],
                             hole=0.3,
                             direction='counterclockwise')])  # Set direction to 'counterclockwise'
fig.update_layout(title='Percentage of Total Amount Received by Top 10 Parties')
fig.show()

# %%
top_10_parties = total_amount_received.head(10)

fig = go.Figure([go.Bar(x=top_10_parties['Name of the Political Party'], 
                        y=top_10_parties['Denomination'])])

fig.update_layout(title='Total Amount Received by Top 10 Parties',
                  xaxis_title='Political Party',
                  yaxis_title='Total Amount Received')

fig.show()

# %%
lok_sabha = pd.read_csv('/home/mustafa/Learning/Projects/Electoral Bond Data Analysis/Dataset/LS_2.0.csv')
lok_sabha.head()
# Out:
#            STATE CONSTITUENCY                   NAME  WINNER PARTY SYMBOL  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO       1   BJP  Lotus
# 1      Telangana     ADILABAD           Godam Nagesh       0   TRS    Car
# 2      Telangana     ADILABAD          RATHOD RAMESH       0   INC   Hand
# 3      Telangana     ADILABAD                   NOTA       0  NOTA    NaN
# 4  Uttar Pradesh         AGRA  Satyapal Singh Baghel       1   BJP  Lotus
#
#   GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# 0   MALE              52  52.0       ST      12th Pass
# 1   MALE               0  54.0       ST  Post Graduate
# 2   MALE               3  52.0       ST      12th Pass
# 3    NaN             NaN   NaN      NaN            NaN
# 4   MALE               5  58.0       SC      Doctorate
#
#                         ASSETS                  LIABILITIES  GENERAL\nVOTES  \
# 0    Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+          376892
# ...

# %%
total_seat_won = lok_sabha.groupby('PARTY')['WINNER'].sum().reset_index()
total_seat_won = total_seat_won.sort_values(by='WINNER', ascending=False)
print(total_seat_won)
# Out:
#           PARTY  WINNER
# 26          BJP     300
# 46          INC      52
# 42          DMK      23
# 131       YSRCP      22
# 13         AITC      22
# ..          ...     ...
# 41         DMDK       0
# 40         CPIM       0
# 39   CPI(ML)(L)       0
# 37          BVA       0
# 57          JHP       0
#
# [133 rows x 2 columns]

# %%
total_amount_received.head(10)
# Out:
#                 Name of the Political Party  Denomination
# 5                      BHARTIYA JANTA PARTY     6060.5111
# 3              ALL INDIA TRINAMOOL CONGRESS     1609.5314
# 17  PRESIDENT, ALL INDIA CONGRESS COMMITTEE     1421.8655
# 4                    BHARAT RASHTRA SAMITHI     1214.7099
# 7                           BIJU JANATA DAL      775.5000
# 8                   DMK PARTY IN PARLIAMENT      639.0000
# 26   YSR CONGRESS PARTY (YUVAJANA SRAMIKA R      337.0000
# 25                       TELUGU DESAM PARTY      218.8800
# 22               SHIVSENA (POLITICAL PARTY)      158.3814
# 19                       RASTRIYA JANTA DAL       72.5000

# %%
party_symbol = {
    'BHARTIYA JANTA PARTY':'BJP',
    'ALL INDIA TRINAMOOL CONGRESS':'TMC',
    'PRESIDENT, ALL INDIA CONGRESS COMMITTEE':'INC',
    'BHARAT RASHTRA SAMITHI':'BRS',
    'BIJU JANATA DAL':'BJD',
    'DMK PARTY IN PARLIAMENT':'DMK',
    'YSR CONGRESS PARTY (YUVAJANA SRAMIKA R':'YSRCP',
    'TELUGU DESAM PARTY':'TDP',
    'SHIVSENA (POLITICAL PARTY)':"SHS",
    'RASTRIYA JANTA DAL':'RJD'
}
total_amount_received['PARTY'] = total_amount_received['Name of the Political Party'].map(party_symbol)
print(total_amount_received)
# Out:
#                        Name of the Political Party  Denomination  PARTY
# 5                             BHARTIYA JANTA PARTY     6060.5111    BJP
# 3                     ALL INDIA TRINAMOOL CONGRESS     1609.5314    TMC
# 17         PRESIDENT, ALL INDIA CONGRESS COMMITTEE     1421.8655    INC
# 4                           BHARAT RASHTRA SAMITHI     1214.7099    BRS
# 7                                  BIJU JANATA DAL      775.5000    BJD
# 8                          DMK PARTY IN PARLIAMENT      639.0000    DMK
# 26          YSR CONGRESS PARTY (YUVAJANA SRAMIKA R      337.0000  YSRCP
# 25                              TELUGU DESAM PARTY      218.8800    TDP
# 22                      SHIVSENA (POLITICAL PARTY)      158.3814    SHS
# 19                              RASTRIYA JANTA DAL       72.5000    RJD
# 0                                  AAM AADMI PARTY       65.4500    NaN
# 12                          JANATA DAL ( SECULAR )       43.5000    NaN
# ...

# %%
result = pd.merge(total_amount_received, total_seat_won, on='PARTY', how='inner')
print(result)
# Out:
#                Name of the Political Party  Denomination  PARTY  WINNER
# 0                     BHARTIYA JANTA PARTY     6060.5111    BJP     300
# 1  PRESIDENT, ALL INDIA CONGRESS COMMITTEE     1421.8655    INC      52
# 2                          BIJU JANATA DAL      775.5000    BJD      11
# 3                  DMK PARTY IN PARLIAMENT      639.0000    DMK      23
# 4   YSR CONGRESS PARTY (YUVAJANA SRAMIKA R      337.0000  YSRCP      22
# 5                       TELUGU DESAM PARTY      218.8800    TDP       3
# 6               SHIVSENA (POLITICAL PARTY)      158.3814    SHS      18
# 7                       RASTRIYA JANTA DAL       72.5000    RJD       0

# %%
colors = ['blue', 'green', 'red', 'orange', 'purple', 'yellow', 'cyan', 'magenta']

fig = go.Figure()

# Add bar trace for number of seats won
fig.add_trace(go.Bar(
    x=result['Name of the Political Party'],
    y=result['WINNER'],
    name='Number of Seats Won',
    marker_color=colors
))

# Update layout
fig.update_layout(
    title='Number of Seats Won by Political Party',
    xaxis=dict(title='Political Party'),
    yaxis=dict(title='Number of Seats Won')
)

fig.show()

# %%
import warnings
warnings.filterwarnings("ignore")
result=result[:len(result)-1]#Ignoring RJD
ratio = []
for i in range(0,len(result)):
    ratio.append(result['Denomination'][i]/result['WINNER'][i])

result['CR recived per seat in lok Sabha'] = ratio
print(result)
# Out:
#                Name of the Political Party  Denomination  PARTY  WINNER  \
# 0                     BHARTIYA JANTA PARTY     6060.5111    BJP     300
# 1  PRESIDENT, ALL INDIA CONGRESS COMMITTEE     1421.8655    INC      52
# 2                          BIJU JANATA DAL      775.5000    BJD      11
# 3                  DMK PARTY IN PARLIAMENT      639.0000    DMK      23
# 4   YSR CONGRESS PARTY (YUVAJANA SRAMIKA R      337.0000  YSRCP      22
# 5                       TELUGU DESAM PARTY      218.8800    TDP       3
# 6               SHIVSENA (POLITICAL PARTY)      158.3814    SHS      18
#
#    CR recived per seat in lok Sabha
# 0                         20.201704
# 1                         27.343567
# 2                         70.500000
# 3                         27.782609
# 4                         15.318182
# 5                         72.960000
# 6                          8.798967

# %%
result = result.sort_values(by='CR recived per seat in lok Sabha', ascending=False)
result
# Out:
#                Name of the Political Party  Denomination  PARTY  WINNER  \
# 5                       TELUGU DESAM PARTY      218.8800    TDP       3
# 2                          BIJU JANATA DAL      775.5000    BJD      11
# 3                  DMK PARTY IN PARLIAMENT      639.0000    DMK      23
# 1  PRESIDENT, ALL INDIA CONGRESS COMMITTEE     1421.8655    INC      52
# 0                     BHARTIYA JANTA PARTY     6060.5111    BJP     300
# 4   YSR CONGRESS PARTY (YUVAJANA SRAMIKA R      337.0000  YSRCP      22
# 6               SHIVSENA (POLITICAL PARTY)      158.3814    SHS      18
#
#    CR recived per seat in lok Sabha
# 5                         72.960000
# 2                         70.500000
# 3                         27.782609
# 1                         27.343567
# 0                         20.201704
# 4                         15.318182
# 6                          8.798967

# %%
colors = ['blue', 'green', 'red', 'orange', 'purple', 'yellow', 'cyan', 'magenta']

fig = go.Figure()

# Add bar trace for number of seats won
fig.add_trace(go.Bar(
    x=result['Name of the Political Party'],
    y=result['WINNER'],
    name='Number of Seats Won',
    marker_color=colors
))

# Update layout
fig.update_layout(
    title='Number of Seats Won by Political Party',
    xaxis=dict(title='Political Party'),
    yaxis=dict(title='Number of Seats Won')
)

fig.show()

# %%
fig = go.Figure()

# Add horizontal bar trace for CR received per seat won
fig.add_trace(go.Bar(
    y=result['Name of the Political Party'],
    x=result['CR recived per seat in lok Sabha'],
    orientation='h',
    marker_color='skyblue'  # You can customize the color as needed
))

# Update layout
fig.update_layout(
    title='CR Received per Seat Won by Political Party',
    xaxis=dict(title='CR Received per Seat in Lok Sabha'),
    yaxis=dict(title='Political Party')
)

fig.show()
